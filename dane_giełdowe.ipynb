# %% [markdown]
# <a href="https://colab.research.google.com/github/wlodarma/udemy-py/blob/main/dane_gie%C5%82dowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
def fetch_financial_data(company='AMZN'):
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2022-11-02 to 2017-11-06
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
df
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2022-11-02   97.3150   97.7400   92.0100   92.1200  135761798
# 2022-11-01  103.9900  104.5800   96.0600   96.7900  153370032
# 2022-10-31  103.5600  104.8700  100.7400  102.4400   99251395
# 2022-10-28   97.9050  103.9600   97.6600  103.4100  223133398
# 2022-10-27  113.9200  114.1200  109.7700  110.9600  129605362
# ...              ...       ...       ...       ...        ...
# 2017-11-10   56.3050   56.5875   56.2030   56.2675   43583620
# 2017-11-09   56.2980   56.4810   55.7885   56.4565   74599560
# 2017-11-08   56.1410   56.7770   55.9555   56.6440   51520200
# 2017-11-07   56.2370   56.5300   55.8750   56.1585   53688860
# 2017-11-06   55.4575   56.2705   55.4385   56.0330   66634760
#
# [1257 rows x 5 columns]

# %%
df.head(3)
# Out:
#                Open    High     Low   Close     Volume
# Date
# 2022-11-02   97.315   97.74   92.01   92.12  135761798
# 2022-11-01  103.990  104.58   96.06   96.79  153370032
# 2022-10-31  103.560  104.87  100.74  102.44   99251395

# %%
df.tail()
# Out:
#                Open     High      Low    Close    Volume
# Date
# 2017-11-10  56.3050  56.5875  56.2030  56.2675  43583620
# 2017-11-09  56.2980  56.4810  55.7885  56.4565  74599560
# 2017-11-08  56.1410  56.7770  55.9555  56.6440  51520200
# 2017-11-07  56.2370  56.5300  55.8750  56.1585  53688860
# 2017-11-06  55.4575  56.2705  55.4385  56.0330  66634760

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.columns = [col.lower() for col in df.columns]

# %%
df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
df.describe()
# Out:
#               open         high          low        close        volume
# count  1257.000000  1257.000000  1257.000000  1257.000000  1.257000e+03
# mean    118.930715   120.346132   117.367981   118.865041  8.608156e+07
# std      36.903507    37.320798    36.423094    36.828693  4.087677e+07
# min      55.457500    56.270500    55.438500    56.033000  1.762674e+07
# 25%      88.225500    88.970000    87.272000    88.212500  5.816222e+07
# 50%     108.104000   110.781000   106.324200   108.000000  7.439198e+07
# 75%     158.338000   159.938000   156.250000   158.100000  1.022881e+08
# max     187.200000   188.654000   184.840000   186.570000  3.113457e+08

# %%
df = df.head(10)

# %%
df.open
# Out:
# Date
# 2022-11-02     97.315
# 2022-11-01    103.990
# 2022-10-31    103.560
# 2022-10-28     97.905
# 2022-10-27    113.920
# 2022-10-26    116.000
# 2022-10-25    119.650
# 2022-10-24    119.980
# 2022-10-21    114.792
# 2022-10-20    113.830
# Name: open, dtype: float64

# %%
df[['open', 'close']]
# Out:
#                open   close
# Date
# 2022-11-02   97.315   92.12
# 2022-11-01  103.990   96.79
# 2022-10-31  103.560  102.44
# 2022-10-28   97.905  103.41
# 2022-10-27  113.920  110.96
# 2022-10-26  116.000  115.66
# 2022-10-25  119.650  120.60
# 2022-10-24  119.980  119.82
# 2022-10-21  114.792  119.32
# 2022-10-20  113.830  115.25

# %%
df.iloc[:,[0, 3]]
# Out:
#                open   close
# Date
# 2022-11-02   97.315   92.12
# 2022-11-01  103.990   96.79
# 2022-10-31  103.560  102.44
# 2022-10-28   97.905  103.41
# 2022-10-27  113.920  110.96
# 2022-10-26  116.000  115.66
# 2022-10-25  119.650  120.60
# 2022-10-24  119.980  119.82
# 2022-10-21  114.792  119.32
# 2022-10-20  113.830  115.25

# %%
df.iloc[:, 3:5]
# Out:
#              close     volume
# Date
# 2022-11-02   92.12  135761798
# 2022-11-01   96.79  153370032
# 2022-10-31  102.44   99251395
# 2022-10-28  103.41  223133398
# 2022-10-27  110.96  129605362
# 2022-10-26  115.66   69002457
# 2022-10-25  120.60   50934609
# 2022-10-24  119.82   49531523
# 2022-10-21  119.32   55660485
# 2022-10-20  115.25   48795104

# %%
df.iloc[:, -1]
# Out:
# Date
# 2022-11-02    135761798
# 2022-11-01    153370032
# 2022-10-31     99251395
# 2022-10-28    223133398
# 2022-10-27    129605362
# 2022-10-26     69002457
# 2022-10-25     50934609
# 2022-10-24     49531523
# 2022-10-21     55660485
# 2022-10-20     48795104
# Name: volume, dtype: int64

# %%
df.loc['20221102']
# Out:
#               open   high    low  close     volume
# Date
# 2022-11-02  97.315  97.74  92.01  92.12  135761798

# %%
df.loc['20221101' : '20221102']
# Out:
#               open   high    low  close     volume
# Date
# 2022-11-02  97.315  97.74  92.01  92.12  135761798

# %%
df = fetch_financial_data('UBER')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 879 entries, 2022-11-02 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    879 non-null    float64
#  1   High    879 non-null    float64
#  2   Low     879 non-null    float64
#  3   Close   879 non-null    float64
#  4   Volume  879 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 41.2 KB

# %%
df = df.head(149)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 149 entries, 2022-11-02 to 2022-04-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    149 non-null    float64
#  1   High    149 non-null    float64
#  2   Low     149 non-null    float64
#  3   Close   149 non-null    float64
#  4   Volume  149 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 7.0 KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  149.000000  149.000000  149.000000  149.000000  1.490000e+02
# mean    27.157081   27.843743   26.478820   27.158121  3.078574e+07
# std      4.071357    4.099567    4.034692    4.054228  1.585368e+07
# min     20.370000   21.125500   19.895000   20.460000  1.292304e+07
# 25%     23.430000   24.060000   22.565000   23.300000  2.129038e+07
# 50%     27.660000   28.340000   26.850000   27.610000  2.704294e+07
# 75%     30.690000   31.675000   30.160000   30.680000  3.293708e+07
# max     36.400000   36.930000   36.215000   36.510000  1.156018e+08

# %%
df['Average'] = (df.Open + df.Close)/2
df.head(3)
# Out:
#              Open     High    Low  Close    Volume  Average
# Date
# 2022-11-02  29.57  30.1600  28.63  28.81  37083453    29.19
# 2022-11-01  30.07  30.9999  29.12  29.75  87994014    29.91
# 2022-10-31  27.61  27.7300  26.30  26.57  37327035    27.09

# %%
df = df.sort_index()
df
# Out:
#               Open     High     Low  Close    Volume  Average
# Date
# 2022-04-01  35.680  36.4800  35.400  35.98  16793293  35.8300
# 2022-04-04  36.400  36.9300  36.215  36.51  20230463  36.4550
# 2022-04-05  36.350  36.6100  34.720  34.96  20984153  35.6550
# 2022-04-06  33.855  34.0000  32.550  33.41  28854792  33.6325
# 2022-04-07  33.340  33.3400  31.020  32.27  34581042  32.8050
# ...            ...      ...     ...    ...       ...      ...
# 2022-10-27  28.400  28.7600  27.660  27.82  16768633  28.1100
# 2022-10-28  27.810  27.8800  26.490  27.50  27116701  27.6550
# 2022-10-31  27.610  27.7300  26.300  26.57  37327035  27.0900
# 2022-11-01  30.070  30.9999  29.120  29.75  87994014  29.9100
# 2022-11-02  29.570  30.1600  28.630  28.81  37083453  29.1900
#
# [149 rows x 6 columns]

# %%
df.Close.shift(1)
# Out:
# Date
# 2022-04-01      NaN
# 2022-04-04    35.98
# 2022-04-05    36.51
# 2022-04-06    34.96
# 2022-04-07    33.41
#               ...
# 2022-10-27    28.20
# 2022-10-28    27.82
# 2022-10-31    27.50
# 2022-11-01    26.57
# 2022-11-02    29.75
# Name: Close, Length: 149, dtype: float64

# %%
df["Close_shift"] = df.Close.shift(1)
df
# Out:
#               Open     High     Low  Close    Volume  Average  Close_shift
# Date
# 2022-04-01  35.680  36.4800  35.400  35.98  16793293  35.8300          NaN
# 2022-04-04  36.400  36.9300  36.215  36.51  20230463  36.4550        35.98
# 2022-04-05  36.350  36.6100  34.720  34.96  20984153  35.6550        36.51
# 2022-04-06  33.855  34.0000  32.550  33.41  28854792  33.6325        34.96
# 2022-04-07  33.340  33.3400  31.020  32.27  34581042  32.8050        33.41
# ...            ...      ...     ...    ...       ...      ...          ...
# 2022-10-27  28.400  28.7600  27.660  27.82  16768633  28.1100        28.20
# 2022-10-28  27.810  27.8800  26.490  27.50  27116701  27.6550        27.82
# 2022-10-31  27.610  27.7300  26.300  26.57  37327035  27.0900        27.50
# 2022-11-01  30.070  30.9999  29.120  29.75  87994014  29.9100        26.57
# 2022-11-02  29.570  30.1600  28.630  28.81  37083453  29.1900        29.75
#
# [149 rows x 7 columns]

# %%
df['Daily_Change'] = df.Close / df.Close_shift - 1
df
# Out:
#               Open     High     Low  Close    Volume  Average  Close_shift  \
# Date
# 2022-04-01  35.680  36.4800  35.400  35.98  16793293  35.8300          NaN
# 2022-04-04  36.400  36.9300  36.215  36.51  20230463  36.4550        35.98
# 2022-04-05  36.350  36.6100  34.720  34.96  20984153  35.6550        36.51
# 2022-04-06  33.855  34.0000  32.550  33.41  28854792  33.6325        34.96
# 2022-04-07  33.340  33.3400  31.020  32.27  34581042  32.8050        33.41
# ...            ...      ...     ...    ...       ...      ...          ...
# 2022-10-27  28.400  28.7600  27.660  27.82  16768633  28.1100        28.20
# 2022-10-28  27.810  27.8800  26.490  27.50  27116701  27.6550        27.82
# 2022-10-31  27.610  27.7300  26.300  26.57  37327035  27.0900        27.50
# 2022-11-01  30.070  30.9999  29.120  29.75  87994014  29.9100        26.57
# 2022-11-02  29.570  30.1600  28.630  28.81  37083453  29.1900        29.75
#
#             Daily_change  Daily_Change
# Date
# ...

# %%
del df['Daily_Change']
df.head()
# Out:
#               Open   High     Low  Close    Volume  Average  Close_shift  \
# Date
# 2022-04-01  35.680  36.48  35.400  35.98  16793293  35.8300          NaN
# 2022-04-04  36.400  36.93  36.215  36.51  20230463  36.4550        35.98
# 2022-04-05  36.350  36.61  34.720  34.96  20984153  35.6550        36.51
# 2022-04-06  33.855  34.00  32.550  33.41  28854792  33.6325        34.96
# 2022-04-07  33.340  33.34  31.020  32.27  34581042  32.8050        33.41
#
#             Daily_change
# Date
# 2022-04-01           NaN
# 2022-04-04      0.014730
# 2022-04-05     -0.042454
# 2022-04-06     -0.044336
# 2022-04-07     -0.034122

# %%
df.Daily_change.min()
# Out:
# -0.11584196394322976

# %%
import seaborn as sns
sns.set()

df.Daily_change.hist(bins=100)

# %%
df.Close.plot()

# %%
df_negative = df[df.Daily_change < 0]
df_negative
# Out:
#               Open     High     Low  Close    Volume  Average  Close_shift  \
# Date
# 2022-04-05  36.350  36.6100  34.720  34.96  20984153  35.6550        36.51
# 2022-04-06  33.855  34.0000  32.550  33.41  28854792  33.6325        34.96
# 2022-04-07  33.340  33.3400  31.020  32.27  34581042  32.8050        33.41
# 2022-04-08  31.920  32.5510  31.580  32.05  17991006  31.9850        32.27
# 2022-04-11  31.360  32.6900  31.110  32.04  19680280  31.7000        32.05
# ...            ...      ...     ...    ...       ...      ...          ...
# 2022-10-26  28.090  28.9801  27.865  28.20  17349542  28.1450        28.36
# 2022-10-27  28.400  28.7600  27.660  27.82  16768633  28.1100        28.20
# 2022-10-28  27.810  27.8800  26.490  27.50  27116701  27.6550        27.82
# 2022-10-31  27.610  27.7300  26.300  26.57  37327035  27.0900        27.50
# 2022-11-02  29.570  30.1600  28.630  28.81  37083453  29.1900        29.75
#
#             Daily_change
# Date
# 2022-04-05     -0.042454
# ...

# %%
df_negative.Daily_change.mean()
# Out:
# -0.03183134890090454

# %%
df[df.Close == df.Low]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Average, Close_shift, Daily_change]
# Index: []

# %%
df.index >'20221001'
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
df[df.index >'20221001']
# Out:
#               Open     High      Low  Close    Volume  Average  Close_shift  \
# Date
# 2022-10-03  26.760  26.9000  25.9600  26.72  19940791  26.7400        26.50
# 2022-10-04  27.625  29.2500  27.5995  29.19  25462214  28.4075        26.72
# 2022-10-05  28.480  29.6500  28.3100  29.18  21458516  28.8300        29.19
# 2022-10-06  29.200  30.2400  28.9600  29.73  25399517  29.4650        29.18
# 2022-10-07  28.830  28.8600  27.9200  28.07  19690232  28.4500        29.73
# 2022-10-10  28.240  28.4500  27.2300  27.53  13413529  27.8850        28.07
# 2022-10-11  25.545  26.0500  22.9400  24.66  92468794  25.1025        27.53
# 2022-10-12  25.050  26.1150  24.5600  25.98  30945853  25.5150        24.66
# 2022-10-13  24.470  26.0250  24.1900  25.00  32838495  24.7350        25.98
# 2022-10-14  25.650  26.0700  24.6600  24.71  22553952  25.1800        25.00
# 2022-10-17  25.260  26.2650  25.0800  25.94  25074914  25.6000        24.71
# ...

# %%
df[(df.index >'20221001') & (df.index < '20221015')]
# Out:
#               Open    High      Low  Close    Volume  Average  Close_shift  \
# Date
# 2022-10-03  26.760  26.900  25.9600  26.72  19940791  26.7400        26.50
# 2022-10-04  27.625  29.250  27.5995  29.19  25462214  28.4075        26.72
# 2022-10-05  28.480  29.650  28.3100  29.18  21458516  28.8300        29.19
# 2022-10-06  29.200  30.240  28.9600  29.73  25399517  29.4650        29.18
# 2022-10-07  28.830  28.860  27.9200  28.07  19690232  28.4500        29.73
# 2022-10-10  28.240  28.450  27.2300  27.53  13413529  27.8850        28.07
# 2022-10-11  25.545  26.050  22.9400  24.66  92468794  25.1025        27.53
# 2022-10-12  25.050  26.115  24.5600  25.98  30945853  25.5150        24.66
# 2022-10-13  24.470  26.025  24.1900  25.00  32838495  24.7350        25.98
# 2022-10-14  25.650  26.070  24.6600  24.71  22553952  25.1800        25.00
#
#             Daily_change
# Date
# 2022-10-03      0.008302
# 2022-10-04      0.092440
# 2022-10-05     -0.000343
# ...

# %%
df[(df.index =='20221003') | (df.index == '20221014')]
# Out:
#              Open   High    Low  Close    Volume  Average  Close_shift  \
# Date
# 2022-10-03  26.76  26.90  25.96  26.72  19940791    26.74         26.5
# 2022-10-14  25.65  26.07  24.66  24.71  22553952    25.18         25.0
#
#             Daily_change
# Date
# 2022-10-03      0.008302
# 2022-10-14     -0.011600

# %%
df
# Out:
#               Open     High     Low  Close    Volume  Average  Close_shift  \
# Date
# 2022-04-01  35.680  36.4800  35.400  35.98  16793293  35.8300          NaN
# 2022-04-04  36.400  36.9300  36.215  36.51  20230463  36.4550        35.98
# 2022-04-05  36.350  36.6100  34.720  34.96  20984153  35.6550        36.51
# 2022-04-06  33.855  34.0000  32.550  33.41  28854792  33.6325        34.96
# 2022-04-07  33.340  33.3400  31.020  32.27  34581042  32.8050        33.41
# ...            ...      ...     ...    ...       ...      ...          ...
# 2022-10-27  28.400  28.7600  27.660  27.82  16768633  28.1100        28.20
# 2022-10-28  27.810  27.8800  26.490  27.50  27116701  27.6550        27.82
# 2022-10-31  27.610  27.7300  26.300  26.57  37327035  27.0900        27.50
# 2022-11-01  30.070  30.9999  29.120  29.75  87994014  29.9100        26.57
# 2022-11-02  29.570  30.1600  28.630  28.81  37083453  29.1900        29.75
#
#             Daily_change
# Date
# 2022-04-01           NaN
# ...

# %%
df[df.index.day == 5]
# Out:
#              Open   High    Low  Close    Volume  Average  Close_shift  \
# Date
# 2022-04-05  36.35  36.61  34.72  34.96  20984153   35.655        36.51
# 2022-05-05  27.87  28.83  26.20  26.83  52804190   27.350        28.10
# 2022-07-05  21.17  22.55  20.83  22.52  24515795   21.845        21.34
# 2022-08-05  31.20  32.63  31.04  32.01  39963623   31.605        31.85
# 2022-10-05  28.48  29.65  28.31  29.18  21458516   28.830        29.19
#
#             Daily_change
# Date
# 2022-04-05     -0.042454
# 2022-05-05     -0.045196
# 2022-07-05      0.055295
# 2022-08-05      0.005024
# 2022-10-05     -0.000343
